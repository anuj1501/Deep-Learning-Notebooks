Grofers – One of the leading e-commerce players in the grocery segment, Grofers started its operations in 2013 and has reached overwhelming heights in the last 5 years. Its wide range of products includes atta, milk, oil, daily need products, vegetables, dairy products, juices, beverages, among others. With its growing reach across India, it has become one of the favorite supermarkets for Indian consumers who want to shop grocery items from the comforts of their homes. 
Digital Mall of Asia – Going live in 2020, Digital Mall of Asia is a very unique concept coined by the founders of Yokeasia Malls. It is designed to provide an immersive digital space equipped with multiple visual and sensory elements to sellers and shoppers. It will also give retailers exclusive rights to sell a particular product category or brand in their respective cities. What makes it unique is its zero-commission model enabling retailers to pay only a fixed amount of monthly rental instead of paying commissions. With its one-of-a-kind features, DMA is expected to bring
never-seen transformation to the current e-commerce ecosystem while addressing all the existing e-commerce worries such as counterfeiting. """

# %%
doc=nlp(article_text)

for ent in doc.ents:
  
  print(ent.text,ent.label_)
# Out:
# India GPE
# one CARDINAL
# Indian NORP
# USD 84 billion MONEY
# 2021 DATE
# USD 24 billion MONEY
# 2017 DATE
# India GPE
# Philip PERSON
# 12% PERCENT
# 2017 DATE
# 22-25% PERCENT
# 2021 DATE
# India GPE
# Amazon ORG
# One CARDINAL
# Amazon ORG
# Amazon ORG
# Amazon Music Limited ORG
# Flipkart PERSON
# 2007 DATE
# Flipkart PERSON
# Indian NORP
# Amazon ORG
# Walmart LOC
# one CARDINAL
# US GPE
# Amazon ORG
# daily DATE
# 2010 DATE
# 2011 DATE
# more than 3 CARDINAL
# India GPE
# over 30 million CARDINAL
# over 125,000 CARDINAL
# Indian NORP
# recent years DATE
# Freecharge PERSON
# Unicommerce GPE
# ShopClues PERSON
# Indian NORP
# ShopClues ORG
# July 2011 DATE
# Gurugram ORG
# INR ORG
# 1.1 billion CARDINAL
# Nexus Venture Partners ORG
# Helion Ventures ORG
# more than 5 CARDINAL
# nine CARDINAL
# Paytm Mall PERSON
# Paytm ORG
# Paytm Mall FAC
# third ORDINAL
# Paytm GPE
# Indian NORP
# Reliance ORG
# Reliance ORG
# India GPE
# Big Basket ORG
# two CARDINAL
# One CARDINAL
# ...

# %%
# Load pre-existing spacy model
nlp = spacy.load('en_core_web_sm')

# Getting the pipeline component
ner = nlp.get_pipe("ner")

# %%
TRAIN_DATA = [
              ("© ADP llp", {"entities": [(2, 9, "ORG")]}),

              ("2019 Copyright Devon Corporation.", {"entities": [(15, 33, "ORG")]}),

              ("2018 Copyright Monsanto Corporation.", {"entities": [(15, 36, "ORG")]}),

              ("1996 Copyright Cardinbox Energy Corporation", {"entities": [(15, 42, "ORG")]}),

              ("2020 Copyright AECOM Corporation", {"entities": [(15, 32, "ORG")]}),

              ("2002-2020 Monsanto Company – All Rights Reserved",{"entities" : [(10,25,"ORG")]}),

              ("2000-2020 Altria Company – All Rights Reserved",{"entities" : [(10,24,"ORG")]}),

              ("1996-2020 Cardinbox Company – All Rights Reserved",{"entities" : [(10,27,"ORG")]}),

              ("1994-2019 Centurylink Company – All Rights Reserved",{"entities" : [(10,29,"ORG")]}),
              
              ("© copyright AECOM llp All Rights Reserved.", {"entities": [(12, 20, "ORG")]}),
              
              ("1999 - 2020 Altria Group, pvt ltd", {"entities": [(12,32, "ORG")]}),
              
              ("Ameriprise Financial llp All rights reserved.", {"entities": [(0,24, "ORG")]}),
              
              ("© 2020 cardinbox technologies pvt ltd", {"entities": [(7,28, "ORG")]}),
              
              ("2019 CenturyLink llp All Rights Reserved.", {"entities": [(5,20, "ORG")]}),
              
              ("1996-2020 C.H. Robinson Worldwide ltd All Rights Reserved.", {"entities": [(10,37, "ORG")]}),
              
              ("Cognizant all rights reserved", {"entities": [(0,9,"ORG")]}),
              
              ("Conagra Brands pvt ltd All Rights Reserved.", {"entities": [(0,22, "ORG")]}),
              
              ("2016 - 2019 Consolidated Edison Company of New York private limited All Rights Reserved.", {"entities": [(12,67, "ORG")]}),
              
              ("2019 Copyright Devon Energy Corporation.", {"entities": [(16,40, "ORG")]}),
              
              ("DISH Network llp All rights reserved.", {"entities": [(0,16, "ORG")]}),
              
              ("© 2020 FirstEnergy Corp. All Rights Reserved", {"entities": [(7,24, "ORG")]}),
              
              ("© Gap private limited All rights reserved", {"entities": [(2,21, "ORG")]}),
              
              ("© Henry Schein private limited All rights reserved.", {"entities": [(8,30, "ORG")]}),
              
              ("INTL FCStone private limited All Rights Reserved", {"entities": [(0,27, "ORG")]}),
              
              ("Illinois Tool Works private limited All Rights Reserved.", {"entities": [(0,23, "ORG")]}),
              
              ("© Kinder Morgan 2015. All rights reserved",{"entities": [(2,15, "ORG")]}),
              
              ("Land O'Lakes pvt ltd All Rights Reserved", {"entities": [(0,20, "ORG")]}),
              
              ("L Brands pvt ltd All Rights Reserved.", {"entities": [(0,15, "ORG")]}),
              
              ("© 2020 Marsh & McLennan Companies private limited", {"entities": [(7,49, "ORG")]}),
              
              ("2002-2020 Monsanto Company – All Rights Reserved", {"entities": [(10,25, "ORG")]}),
              
              ("PPG Industries limited All Rights Reserved.", {"entities": [(0,22, "ORG")]}),
              
              ("Reynolds American limited All Rights Reserved", {"entities": [(0,26, "ORG")]}),
              
              ("Ross Stores, private limited All rights reserved", {"entities": [(0,29, "ORG")]}),
              
              ("Ross Stores, pvt ltd All rights reserved", {"entities": [(0,19, "ORG")]}),
              
              ("Synchrony limited All Rights Reserved ", {"entities": [(0,18, "ORG")]}),
              
              ("2004-2020 Textron limited All Rights Reserved.", {"entities": [(10,25, "ORG")]}),
              
              ("2004-2020 Textron ltd All Rights Reserved.", {"entities": [(10,20, "ORG")]}),
              
              ("2020 WellCare pvt ltd", {"entities": [(5,20, "ORG")]}),
              
              ("2020 WellCare private limited", {"entities": [(5,20, "ORG")]}),
              
              ("XPO Logistics private limited All rights reserved.", {"entities": [(0,28, "ORG")]})
              
              ]

# %%
# Adding labels to the `ner`

for _, annotations in TRAIN_DATA:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
# Disable pipeline components you dont need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
# Import requirements
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# %%
# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):

  optimizer = nlp.begin_training()
  # Training for 30 iterations
  for iteration in range(10):

    # shuufling examples  before every iteration
    random.shuffle(TRAIN_DATA)
    losses = {}
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,
                    sgd = optimizer,  # dropout - make it harder to memorise data
                    losses=losses,
                )
    print("trained on epoch {}/{}".format(iteration+1,10))
# Out:
# trained on epoch 1/10
# trained on epoch 2/10
# trained on epoch 3/10
# trained on epoch 4/10
# trained on epoch 5/10
# trained on epoch 6/10
# trained on epoch 7/10
# trained on epoch 8/10
# trained on epoch 9/10
# trained on epoch 10/10

# %%
# Testing the model

doc = nlp("Ross Stores private limited All rights reserved. All merchandise is representative of the merchandise carried in our stores.Cardinbox technologies pvt ltd All rights reserved, will vary by store.")

print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('Ross Stores private limited', 'ORG'), ('Cardinbox technologies pvt ltd', 'ORG')]

# %%
from spacy import displacy

displacy.render(doc, jupyter = True, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ross Stores private limited
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  All rights reserved. All merchandise is representative of the merchandise carried in our stores.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cardinbox technologies pvt ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  All rights reserved, will vary by store.</div></span>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-511d3a8c-f659-4cd8-bfc0-b605344815ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-511d3a8c-f659-4cd8-bfc0-b605344815ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving company_info_2.0.csv to company_info_2.0.csv
# ...

# %%
import pandas as pd
data = pd.read_csv("company_info_2.0.csv")

print(data.columns)
# Out:
# Index(['Domain', 'Title', 'Description', 'Name', 'keywords', 'Image', 'Emails',
#        'OG_data', 'Social_media_links', 'Contact_info'],
#       dtype='object')

# %%
for i in range(len(data)):

  init_name = str(data.loc[i,"Name"])

  doc = nlp(init_name)

  print("Initial name : ",init_name)

  print("NER extracted name : ",[(ent.text, ent.label_) for ent in doc.ents])

  print()
# Out:
# Initial name :  © ADP, LLC.
# NER extracted name :  [('ADP, LLC', 'ORG')]
#
# Initial name :  AECOM. All Rights Reserved.
# NER extracted name :  []
#
# Initial name :  1996-2020
# NER extracted name :  []
#
# Initial name :  1999 - 2020 Altria Group, Inc.
# NER extracted name :  [('Altria Group, Inc.', 'ORG')]
#
# Initial name :  Ameriprise Financial, Inc. All rights reserved.
# NER extracted name :  [('Ameriprise Financial,', 'ORG')]
#
# Initial name :  Not Available
# NER extracted name :  []
#
# Initial name :  © 2020 Arconic
# NER extracted name :  []
#
# Initial name :  document.write(new Date().getFullYear());
# NER extracted name :  []
#
# Initial name :  BD. All rights reserved. Unless otherwise noted, BD, the BD Logo and all other trademarks are the property of Becton, Dickinson and Company or its affiliates.
# NER extracted name :  [('BD', 'ORG'), ('BD', 'ORG'), ('BD Logo', 'ORG'), ('Becton', 'GPE')]
#
# Initial name :  Bed Bath & Beyond Inc. and its subsidiaries.
# ...
